# %%
import illoominate
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_df = pd.read_csv("train.csv",)
validation_df = pd.read_csv("valid.csv")
test_df = pd.read_csv("test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train_df = pd.read_csv("train.csv",)
#       2 validation_df = pd.read_csv("valid.csv")
#       3 test_df = pd.read_csv("test.csv")
#
# File D:\git\illoominate\venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File D:\git\illoominate\venv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File D:\git\illoominate\venv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File D:\git\illoominate\venv\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File D:\git\illoominate\venv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.csv'

# %%
loo_values = illoominate.data_loo_values(
    train_df=train_df,
    validation_df=validation_df,
    model='vmis',
    metric='mrr@20',
    params={'m':100, 'k':100, 'seed': 42},
)

plt.hist(loo_values['score'], density=False, bins=100)
plt.title('Distribution of Data LOO Values')
plt.yscale('log')
plt.ylabel('Frequency')
plt.xlabel('Data LOO Values')
plt.show()

# %%
shapley_values = illoominate.data_shapley_values(
    train_df=train_df,
    validation_df=validation_df,
    model='vmis',
    metric='mrr@20',
    params={'m':100, 'k':100, 'seed': 42},
)


plt.hist(shapley_values['score'], density=False, bins=100)
plt.title('Distribution of Data Shapley Values')
plt.yscale('log')
plt.ylabel('Frequency')
plt.xlabel('Data Shapley Values')
plt.savefig('images/shapley.png', dpi=300)
plt.show()
# Out:
# [2024-11-18T09:23:19 illoominate::importance::k_mc_shapley] INFO random_score_dataset()
# [2024-11-18T09:23:19 illoominate::importance::k_mc_shapley] INFO random_score: 0.0000 _random_stddev_score: 0.0000
# [2024-11-18T09:23:19 illoominate::importance::tmc_utils] WARN mem length 10 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:19 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:19 illoominate::importance::tmc_utils] WARN mem length 20 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:19 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:20 illoominate::importance::tmc_utils] WARN mem length 30 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:20 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:20 illoominate::importance::tmc_utils] WARN mem length 40 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:20 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:20 illoominate::importance::tmc_utils] WARN mem length 50 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:20 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:21 illoominate::importance::tmc_utils] WARN mem length 60 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:21 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:21 illoominate::importance::tmc_utils] WARN mem length 70 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:21 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:21 illoominate::importance::tmc_utils] WARN mem length 80 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:21 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:21 illoominate::importance::tmc_utils] WARN mem length 90 is below qty_minimal_mc_iterations: 100. Returning 1.0 error
# [2024-11-18T09:23:21 illoominate::importance::k_mc_shapley] INFO mc_error: 1.0
# [2024-11-18T09:23:22 illoominate::importance::k_mc_shapley] INFO mc_error: 0.02215165788931622
# [2024-11-18T09:23:22 illoominate::importance::k_mc_shapley] INFO iterations used: 100

# %%
negative = shapley_values[shapley_values.score < 0]
corrupt_sessions = train_df.merge(negative, on='session_id')
corrupt_sessions
# Out:
#      session_id  item_id   timestamp         score
# 0          5076       64  1585507853 -2.931978e-05
# 1         13946      119  1584189394 -2.606203e-05
# 2         13951      173  1585417176 -6.515507e-06
# 3          3090      199  1584196605 -2.393995e-05
# 4          5076      205  1585507872 -2.931978e-05
# ..          ...      ...         ...           ...
# 956       13951     5860  1585416925 -6.515507e-06
# 957         447     3786  1584448579 -5.092383e-06
# 958        7573    14467  1584450303 -7.107826e-07
# 959        5123       47  1584808576 -4.295939e-07
# 960       11339     4855  1585391332 -1.579517e-06
#
# [961 rows x 4 columns]

# %%
# Out:
#      session_id  item_id   timestamp         score
# 0          5076       64  1585507853 -2.931978e-05
# 1         13946      119  1584189394 -2.606203e-05
# 2         13951      173  1585417176 -6.515507e-06
# 3          3090      199  1584196605 -2.393995e-05
# 4          5076      205  1585507872 -2.931978e-05
# ..          ...      ...         ...           ...
# 956       13951     5860  1585416925 -6.515507e-06
# 957         447     3786  1584448579 -5.092383e-06
# 958        7573    14467  1584450303 -7.107826e-07
# 959        5123       47  1584808576 -4.295939e-07
# 960       11339     4855  1585391332 -1.579517e-06
#
# [961 rows x 4 columns]
